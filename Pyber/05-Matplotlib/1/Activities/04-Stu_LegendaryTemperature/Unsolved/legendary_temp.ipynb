# %%
# Include this line to make plots interactive
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
x_axis = np.arange(1,13,1)
# Avearge weather temp
points_F = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]
# Convert to Celsius C = (F-32) * 0.56
points_C = [(x-32) * 0.56 for x in points_F]
points_C
# Out:
# [3.9200000000000004,
#  5.6000000000000005,
#  10.64,
#  16.8,
#  22.400000000000002,
#  28.000000000000004,
#  30.240000000000002,
#  29.120000000000005,
#  25.200000000000003,
#  18.48,
#  12.88,
#  6.720000000000001]

# %%
Fahr,=plt.plot(x_axis,points_F,label="Fahrenheit",color="blue",marker="+")
Cels,=plt.plot(x_axis,points_C,label="Celsius",color="red",marker="^")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.legend(handles=[Fahrenheit,"Cel"], loc="best")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-127908af3dd1> in <module>()
# ----> 1 plt.legend(handles=["Fahrenheit","Cel"], loc="best")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    3742 @docstring.copy_dedent(Axes.legend)
#    3743 def legend(*args, **kwargs):
# -> 3744     ret = gca().legend(*args, **kwargs)
#    3745     return ret
#    3746
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     495                 [self],
#     496                 *args,
# --> 497                 **kwargs)
#     498         if len(extra_args):
#     499             raise TypeError('legend only accepts two non-keyword arguments')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\legend.py in _parse_legend_args(axs, *args, **kwargs)
#    1364
#    1365     elif handles is not None and labels is None:
# -> 1366         labels = [handle.get_label() for handle in handles]
#    1367
#    1368     elif labels is not None and handles is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\legend.py in <listcomp>(.0)
#    1364
#    1365     elif handles is not None and labels is None:
# -> 1366         labels = [handle.get_label() for handle in handles]
#    1367
#    1368     elif labels is not None and handles is None:
#
# AttributeError: 'str' object has no attribute 'get_label'
